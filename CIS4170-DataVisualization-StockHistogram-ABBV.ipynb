# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('ABBV.csv')
ABBV=df['ABBVreturn_Perc']

# %%
df.head(1)
# Out:
#   ABBVreturn_Perc
# 0          -0.95%

# %%
plt.hist(df['ABBVreturn_Perc'], bins=80, align='right', color='yellow', edgecolor='black')
plt.xlabel("ABBVreturn in percentage")
# Out:
# Text(0.5, 0, 'ABBVreturn in percentage')
