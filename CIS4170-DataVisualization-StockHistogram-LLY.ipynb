# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('LLY.csv')
LLY=df['LLYreturn_Perc']
df.head(1)
# Out:
#   LLYreturn_Perc
# 0         -0.33%

# %%
plt.hist(df['LLYreturn_Perc'], bins=250, align='right', color='coral', edgecolor='black')
plt.xlabel("LLYreturn in percentage")
# Out:
# Text(0.5, 0, 'LLYreturn in percentage')
