# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('REGN.csv')
REGN=df[' REGNreturn_Perc']
df.head(1)
# Out:
#    REGNreturn_Perc
# 0           -1.12%

# %%
plt.hist(df[' REGNreturn_Perc'], bins=80, align='right', color='lime', edgecolor='black')
plt.xlabel("REGNreturn in percentage")
# Out:
# Text(0.5, 0, 'REGNreturn in percentage')
