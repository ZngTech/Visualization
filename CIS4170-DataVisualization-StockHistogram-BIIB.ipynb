# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('BIIB.csv')
BIIB=df['BIIBreturn_Perc']

# %%
df.head(1)
# Out:
#    BIIBreturn_Perc  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           -1.15%         NaN         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN

# %%
plt.hist(df['BIIBreturn_Perc'], bins=80, align='right', color='purple', edgecolor='black')
plt.xlabel("BIIBreturn in percentage")
# Out:
# Text(0.5, 0, 'BIIBreturn in percentage')
