# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('BMY.csv')
BMY=df['BMYreturn_Perc']
df.head(1)
# Out:
#   BMYreturn_Perc
# 0         -0.88%

# %%
plt.hist(df['BMYreturn_Perc'], bins=80, align='right', color='black', edgecolor='black')
plt.xlabel("BMYreturn in percentage")
# Out:
# Text(0.5, 0, 'BMYreturn in percentage')
