# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
# Import Dataset
import pandas as pd
df=pd.read_csv('PFE.csv')
df.head(1)
# Out:
#    PFEreturn_Perc
# 0          -0.54%

# %%
PFE=df[' PFEreturn_Perc']

# %%
plt.hist(df[' PFEreturn_Perc'], bins=100, align='right', color='blue', edgecolor='black')
plt.xlabel("PFEreturn in percentage")
# Out:
# Text(0.5, 0, 'PFEreturn in percentage')
