# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
# Import Dataset
import pandas as pd
df=pd.read_csv('JNJ.csv')
df.head(1)
# Out:
#   JNJreturn_Perc
# 0         -1.16%

# %%
import os
os.getcwd()
# Out:
# '/Users/efz'

# %%
JNJ=df['JNJreturn_Perc']

# %%
#check if the file was successfully read in
JNJ.head(1)
# Out:
# 0    -1.158%
# Name: JNJreturn_Perc, dtype: object

# %%
import matplotlib.pyplot as plt
print(JNJ.describe())
# Out:
# count         601
# unique        551
# top       -0.221%
# freq            3
# Name: JNJreturn_Perc, dtype: object

# %%
JNJ
# Out:
# 0      -1.158%
# 1      -0.125%
# 2       0.611%
# 3      -0.014%
# 4       0.297%
#         ...
# 596     0.696%
# 597     0.416%
# 598    -1.857%
# 599    -0.889%
# 600     1.748%
# Name: JNJreturn_Perc, Length: 601, dtype: object

# %%
plt.hist(df['JNJreturn_Perc'], bins=80, align='right', color='green', edgecolor='black')
plt.xlabel("JNJreturn in percentage")
# Out:
# Text(0.5, 0, 'JNJreturn in percentage')

# %%
### The return in percentage of JNJ stock ADJclose Price follows a near bell-curve distribution.
