# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('SYK.csv')
SYK=df[' SYKreturn_Perc']
df.head(1)
# Out:
#    SYKreturn_Perc
# 0          -0.41%

# %%
plt.hist(df[' SYKreturn_Perc'], bins=80, align='right', color='pink', edgecolor='black')
plt.xlabel("SYKreturn in percentage")
# Out:
# Text(0.5, 0, 'SYKreturn in percentage')
