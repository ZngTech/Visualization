# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# Import Dataset
import pandas as pd

# %%
df=pd.read_csv('ABT.csv')
ABT=df['ABTreturn_Perc']

# %%
df.head(1)
# Out:
#   ABTreturn_Perc
# 0         -1.22%

# %%
plt.hist(df['ABTreturn_Perc'], bins=80, align='right', color='teal', edgecolor='black')
plt.xlabel("ABTreturn in percentage")
# Out:
# Text(0.5, 0, 'ABTreturn in percentage')
