# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
# Import Dataset
import pandas as pd
df=pd.read_csv('MRK.csv')
df.head(1)
# Out:
#   MRKreturn_Perc
# 0         -0.86%

# %%
MRK=df['MRKreturn_Perc']

# %%
plt.hist(df['MRKreturn_Perc'], bins=80, align='right', color='red', edgecolor='black')
plt.xlabel("MRKreturn in percentage")
# Out:
# Text(0.5, 0, 'MRKreturn in percentage')
